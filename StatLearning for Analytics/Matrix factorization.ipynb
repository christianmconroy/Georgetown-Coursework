# %%
from sklearn import datasets 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
digits_data = datasets.load_digits()

# %%
digits = digits_data['images']
labels = digits_data['target']

# %%
i = 100
plt.matshow

# %%
plt.matshow(faces[4], cmap = 'gray')
plt.show
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-d97dfc1bd9a2> in <module>()
# ----> 1 plt.matshow(faces[4], cmap = 'gray')
#       2 plt.show
#
# NameError: name 'plt' is not defined

# %%
from sklearn.decomposition import PCA, NMF, FastICA

Algo = PCA
data = digits
k = 10

data_flat = data.reshape(data.shape[0], -1)
print(data_flat.shape)

algo = Algo(n_components=k)

w = algo.fit_transform(data_flat)
h = algo.components_
print(w.shape, h.shape)
# Out:
# (1797, 64)
# (1797, 10) (10, 64)

# %%
h = h.reshape(h.shape[0], *data.shape[1:])
print(h.shape)
# Out:
# (10, 8, 8)

# %%
plt.matshow(h[2], cmap='gray_r')
plt.show()

# %%
plt.scatter(w[:,0], w[:, 1], c=labels, cmap='Set2');
plt.colorbar();
plt.show()

# %%
from sklearn.decomposition import PCA, NMF, FastICA

Algo = NMF
data = digits
k = 10

data_flat = data.reshape(data.shape[0], -1)
print(data_flat.shape)

algo = Algo(n_components=k)

w = algo.fit_transform(data_flat)
h = algo.components_
print(w.shape, h.shape)
# Out:
# (1797, 64)
# (1797, 10) (10, 64)
